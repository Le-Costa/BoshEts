# %%
import pandas as pd

# %%
titanic= pd.read_csv("titanic.csv",sep=",") #prametro de separador

# %%
titanic.head() # 5 primeiras linhas
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()#ultimas linhas
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic["Name"].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
titanic.Name.head(15)
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
print(titanic.shape)
print(titanic.index)
# Out:
# (891, 12)
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#FILTROS
TipoNum = (titanic.dtypes ==  "object")
print(TipoNum)
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
colNumericas = titanic.dtypes[TipoNum].index
print(colNumericas)
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic[colNumericas].head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
colunas_selecionadas = ["PassengerId","SibSp","Parch"]
titanic[colunas_selecionadas].head()
# Out:
#    PassengerId  SibSp  Parch
# 0            1      1      0
# 1            2      1      0
# 2            3      0      0
# 3            4      1      0
# 4            5      0      0

# %% [markdown]
# Como retornamos um DataFrame com todas as colunas menos a última?

# %%
titanic[:-1] #todo o dataframe
titanic.columns[:-1] # só as colunas
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin'],
#       dtype='object')

# %%
titanic.iloc[:,:-1].head() #iloc seleciona os indices por linha e coluna
titanic.iloc[15:,:3].head()

# %%
titanic.loc[:,["Survived","Name"]].head()#loc seleciona pelo nome da coluna
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0                           Allen, Mr. William Henry

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe(include="all") #valores de todas as colunas
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
titanic.loc[:,["Age","Pclass"]].describe()
titanic[["Age","Pclass"]].describe()
# Out:
#               Age      Pclass
# count  714.000000  891.000000
# mean    29.699118    2.308642
# std     14.526497    0.836071
# min      0.420000    1.000000
# 25%     20.125000    2.000000
# 50%     28.000000    3.000000
# 75%     38.000000    3.000000
# max     80.000000    3.000000

# %%
titanic["Age"].mean()#estatistica de uma só coluna

# %% [markdown]
# Importe as colunas ‘crim’ e ‘medv’ do dataset BostonHousing.
# Mostre somente as primeiras 14 linhas.

# %%
boston = pd.read_csv("BostonHousing.csv")
boston.loc[:13,["crim","medv"]]
# Out:
#        crim  medv
# 0   0.00632  24.0
# 1   0.02731  21.6
# 2   0.02729  34.7
# 3   0.03237  33.4
# 4   0.06905  36.2
# 5   0.02985  28.7
# 6   0.08829  22.9
# 7   0.14455  27.1
# 8   0.21124  16.5
# 9   0.17004  18.9
# 10  0.22489  15.0
# 11  0.11747  18.9
# 12  0.09378  21.7
# 13  0.62976  20.4

# %%
boston[["crim","medv"]].head(14)
# Out:
#        crim  medv
# 0   0.00632  24.0
# 1   0.02731  21.6
# 2   0.02729  34.7
# 3   0.03237  33.4
# 4   0.06905  36.2
# 5   0.02985  28.7
# 6   0.08829  22.9
# 7   0.14455  27.1
# 8   0.21124  16.5
# 9   0.17004  18.9
# 10  0.22489  15.0
# 11  0.11747  18.9
# 12  0.09378  21.7
# 13  0.62976  20.4

# %%
titanic.Embarked.unique() #valores unicos
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
titanic.Age.value_counts()# contagem de qnts vezes os valores aparecem
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
new = titanic.dropna()# exclui todas as linhas com nan
#print(titanic.isna().head(15))
print(titanic.isna().sum())#conta os valores verdadeiros
new.shape
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# (183, 12)

# %%
y = titanic.Age.fillna(titanic["Age"].mean())#preenchendo os na com a media na coluna Age
print(y.head(15))
z= titanic.fillna(200)#preenchendo na com valor 200 em todas as colunas vazia
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     29.699118
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# Name: Age, dtype: float64

# %%
print(round(titanic.groupby("Embarked").mean()["Age"].sort_values()["S"],5))#separa os valores de embarked;.mean()-> media de idade do grupo S
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\disrct\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
#varios filtros de uma vez

rico = titanic["Pclass"] == 1
sobreviveu = titanic["Survived"] == 1
titanic[rico & sobreviveu ].describe()
# Out:
#        PassengerId  Survived  Pclass         Age       SibSp       Parch  \
# count   136.000000     136.0   136.0  122.000000  136.000000  136.000000
# mean    491.772059       1.0     1.0   35.368197    0.492647    0.389706
# std     239.006988       0.0     0.0   13.760017    0.632412    0.690387
# min       2.000000       1.0     1.0    0.920000    0.000000    0.000000
# 25%     307.750000       1.0     1.0   24.250000    0.000000    0.000000
# 50%     510.500000       1.0     1.0   35.000000    0.000000    0.000000
# 75%     693.500000       1.0     1.0   45.000000    1.000000    1.000000
# max     890.000000       1.0     1.0   80.000000    3.000000    2.000000
#
#              Fare
# count  136.000000
# mean    95.608029
# std     85.286820
# min     25.929200
# 25%     50.985450
# 50%     77.958300
# 75%    111.481225
# max    512.329200

# %% [markdown]
# E se quisermos um filtro que retorne os registros com os passageiros da primeira
# classe que sobreviveram
# 1.13 e os passageiros da terceira classe que não sobreviveram?

# %%
#filtro = (titanic["Pclass" == 1 ] & titanic["Survived"] ==1) | (titanic["Pclass"]==3 & titanic["Survived"]==0)
#titanic[((titanic["Pclass" == 1 ] & titanic["Survived"] ==1) | (titanic["Pclass"]==3 & titanic["Survived"]==0))].head() -> () foi o erro
filtro = (
(titanic["Pclass"] == 1) & (titanic["Survived"] == 1) |
(titanic["Pclass"] == 3) & (titanic["Survived"] == 0)
)
titanic[filtro].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 3      0     113803  53.1000  C123        S
# 4      0     373450   8.0500   NaN        S
# 5      0     330877   8.4583   NaN        Q
